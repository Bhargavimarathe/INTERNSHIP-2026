# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavimarathe/INTERNSHIP-2026/blob/main/daily_codes/week7/dt_july9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# banknotes.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('banknotes.csv')
df
# Out:
#       Variance  Skewness  Curtosis  Entropy  Class
# 0      3.62160   8.66610   -2.8073 -0.44699      0
# 1      4.54590   8.16740   -2.4586 -1.46210      0
# 2      3.86600  -2.63830    1.9242  0.10645      0
# 3      3.45660   9.52280   -4.0112 -3.59440      0
# 4      0.32924  -4.45520    4.5718 -0.98880      0
# ...        ...       ...       ...      ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1
#
# [1372 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Variance  1372 non-null   float64
#  1   Skewness  1372 non-null   float64
#  2   Curtosis  1372 non-null   float64
#  3   Entropy   1372 non-null   float64
#  4   Class     1372 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 53.7 KB

# %%
df.isnull().sum()
# Out:
# Variance    0
# Skewness    0
# Curtosis    0
# Entropy     0
# Class       0
# dtype: int64

# %%
# check for pattern through viz

# %%
sns.pairplot(df, hue = 'Class');

# %%
# check the distribution of target variable (countplot)

# %%
x = df.drop('Class', axis = 1)
y = df['Class']

# %%
sns.countplot(x = y);

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    762
# 1    610
# Name: count, dtype: int64

# %%
# cross val

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y,
                                                    random_state=0, test_size=0.25)

# %%
x_train.shape, y_train.shape
# Out:
# ((1029, 4), (1029,))

# %%
# build the decision tree
# and also evaluate

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# evaluate

# %%
y_pred = dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9883381924198251

# %%
x.columns
# Out:
# Index(['Variance', 'Skewness', 'Curtosis', 'Entropy'], dtype='object')

# %%
dt.feature_importances_
# Out:
# array([0.60052599, 0.2197106 , 0.15040355, 0.02935987])

# %%
# plot the graph to viz feature importances

# %%
plt.title("feature importances")
plt.xlabel('features')
plt.ylabel("importance")
plt.bar(x.columns, dt.feature_importances_);

# %%
# plot the tree

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(16, 12))
plot_tree(dt, rounded= True, fontsize= 7, filled= True,
          class_names= ['Original', 'Fake'],
          feature_names= x.columns);

# %%
"""
4.86600
-1.63830
0.9242
0.645


""";

# %%
new = [[4.86600	,
-1.63830,
0.9242,
0.645]]

# %%
dt.predict(new)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
