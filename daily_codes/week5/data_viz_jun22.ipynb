# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavimarathe/BhargaviMarathe/blob/main/daily_codes/week5/data_viz_jun22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([10,23,29,34,39,45,50])
y=np.array([14,21,31,43,48,55,58])
z=np.array([56,50,44,37,26,20,16])

# %%
plt.plot(x,y)

# %%
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("line chart: x as y")
plt.plot(x,y)

# %%
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("Line Chart: x vs y")
plt.plot(x, y, marker='o', mfc='red', ls='--')
plt.grid()
# o,*,H,<,>,^

# %%
plt.plot(x,x);
