# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavimarathe/INTERNSHIP-2026/blob/main/daily_codes/week5/data_viz2_june23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=np.array([10,23,29,34,39,45,50])
y=np.array([14,21,31,43,48,55,58])
z=np.array([56,50,44,37,26,20,16])

# %%
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("line chart: x vs y")
plt.plot(x, y, marker = 'o', mfc= 'red', ls = '--');
plt.grid();
# o, *, H, <, >, ^

# %%
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("line chart: x vs y")
plt.plot(x, z, marker = 'o', mfc= 'orange', ls = '--');
plt.grid();
# o, *, H, <, >, ^

# %%
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("line chart: x vs y")

plt.plot(x, y, marker='o', mfc='red', ls='--', label='2024')
plt.plot(x, z, marker='o', mfc='black', ls='-.', color='orange', label='2025')

plt.grid()
plt.legend()

# %%
plt.figure(figsize=(16, 9))

plt.subplot(2, 2, 1)
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("Line Chart: x vs y")
plt.plot(x, y, marker='o', mfc='red', ls='--')
plt.grid()

plt.subplot(2, 2, 2)
plt.xlabel("x values")
plt.ylabel("z values")
plt.title("Line Chart: x vs z")
plt.plot(x, z, marker='o', mfc='red', ls='--')
plt.grid()

# %%
# bar chart

# %%
courses = ['python', 'lisp', 'c', 'R', 'php']
students = [68, 30, 47, 39, 60]

# %%
plt.title("student enrollment")
plt.xlabel("course")
plt.ylabel("no. of students enrolled")

plt.bar(courses, students,color='cyan',edgecolor='red')

plt.grid()

# %%
# load student.csv file and create a bar chart of students and marks

# %%
df = pd.read_csv("student.csv")

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
plt.title("student marks")
plt.xlabel("name")
plt.ylabel("marks")

plt.xticks(rotation=45)
plt.bar(df['name'],df['marks'],color='red')
# Out:
# <BarContainer object of 10 artists>

# %%
# load social network.ads.csv
# plot bar graph showing  the count of how many people purhased and how many did not
# purchased column= 0 = purchased, 1 == not purchased

# %%
df = pd.read_csv("Social_Network_Ads.csv")

# %%
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
counts = df['Purchased'].value_counts()

plt.title("Purchase Status")
plt.xlabel("Status")
plt.ylabel("Count")

plt.bar(
    ['Purchased', 'Not Purchased'],[counts[0], counts[1]],
    color=['green', 'red']
)
# Out:
# <BarContainer object of 2 artists>

# %%
# scatter chart

# %%
plt.scatter(x,y,color='red');

# %%
df.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
plt.figure(figsize=(16,9))
plt.scatter(df['EstimatedSalary'],df['Age'],c= df['Purchased']);

# %%
import seaborn as sns

# %%
iris= sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris);

# %%
sns.pairplot(iris,hue='species');

# %%
# universal analysis
plt.xticks(range(0,70,2),rotation= 45)
plt.yticks(range(0,80,5))
plt.hist(df["Age"],bins=15);

# %%
"""
outlier= extreme value which is not following the crowd/ away from other values-> introvert/isolated
""";

# %%
# for the age col, on put the following values at that index

# 2->8, 3->85

# %%
df.loc[[2, 3], 'Age'] = [5, 85]

# %%
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female   5.0          43000.0          0
# 3    15603246  Female  85.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
plt.boxplot(df["Age"]);

# %%
# create a function to remove outliers

# %%
def remove_outliers(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df_clean= df[(df[columns]>=lower_bound)and (df[columns]<= upper_bound)]
    return df_clean

# %%
print(outliers)
# Out:
#     User ID  Gender   Age  EstimatedSalary  Purchased
# 2  15668575  Female   5.0          43000.0          0
# 3  15603246  Female  85.0          57000.0          0

# %%
# practice =>
# load the tips dataset  from seaborn
# do detailed EDA ( charts along with explaination of what we are
# understanding from them )
# u can use officiail documentation for ref

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
print("First 5 Rows:")
print(tips.head())

print("\nDataset Info:")
print(tips.info())

print("\nSummary Statistics:")
print(tips.describe())
# Out:
# First 5 Rows:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None
#
# Summary Statistics:
# ...

# %%
plt.figure(figsize=(6,4))
sns.histplot(tips['total_bill'], bins=20, kde=True)
plt.title("Distribution of Total Bill")
# Out:
# Text(0.5, 1.0, 'Distribution of Total Bill')

# %%
plt.figure(figsize=(6,4))
sns.histplot(tips['tip'], bins=20, kde=True)
plt.title("Distribution of Tips")
# Out:
# Text(0.5, 1.0, 'Distribution of Tips')

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title("Total Bill vs Tip")
# Out:
# Text(0.5, 1.0, 'Total Bill vs Tip')
