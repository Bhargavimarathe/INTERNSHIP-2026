# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavimarathe/BhargaviMarathe/blob/main/daily_codes/week4/pandas_jun15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pandas

# %%
# 1D data structure in pandas

# %%
# pandas series is a one dimensional array capableof holding any data type

# %%
# creating  pandas series

# %%
import pandas as pd

# %%
s= pd.Series([10,20,30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s= pd.Series([22,44,66,88])

# %%
s
# Out:
# 0    22
# 1    44
# 2    66
# 3    88
# dtype: int64

# %%
# with custom index

# %%
s = pd.Series([10, 20, 30], index=['a', 'b', 'c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s = pd.Series(['bhargavi', 18, 93.42], index=['name', 'age', 'marks'])

# %%
s
# Out:
# name     bhargavi
# age            18
# marks       93.42
# dtype: object

# %%
# from dictionary

# %%
data = {'name':"bhargavi",'age':18,'marks': 92.59}

# %%
data
# Out:
# {'name': 'bhargavi', 'age': 18, 'marks': 92.59}

# %%
s= pd.Series(data)

# %%
s
# Out:
# name     bhargavi
# age            18
# marks       92.59
# dtype: object

# %%
data = {'name':"bhargavi",'sub':"DSU",'year': 'SY','marks': 100}

# %%
s=pd.Series(data)

# %%
s
# Out:
# name     bhargavi
# sub           DSU
# year           SY
# marks         100
# dtype: object

# %%
# from a single value

# %%
s = pd.Series(5, index=[0,1,2,3])

# %%
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
#attributes

# %%
s=pd.Series([10,20,30], index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.size
# Out:
# 3

# %%
s.shape
# Out:
# (3,)

# %%
# data manipulation

# %%
s=  pd.Series([1,2,3,4,])

# %%
print(s*3)
# Out:
# 0     3
# 1     6
# 2     9
# 3    12
# dtype: int64

# %%
print(s+3)
# Out:
# 0    4
# 1    5
# 2    6
# 3    7
# dtype: int64

# %%
# handeling missing values

# %%
s=pd.Series([1,None,3])

# %%
s
# Out:
# 0    1.0
# 1    NaN
# 2    3.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s.dropna()
# Out:
# 0    1.0
# 2    3.0
# dtype: float64

# %%
s.fillna(0)
# Out:
# 0    1.0
# 1    0.0
# 2    3.0
# dtype: float64

# %%
# indexing

# %%
s = pd.Series([10,20,30], index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s['a']
# Out:
# np.int64(10)

# %%
s['c']
# Out:
# np.int64(30)
