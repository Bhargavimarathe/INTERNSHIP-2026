# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavimarathe/BhargaviMarathe/blob/main/daily_codes/week4/exception_handling_jun17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f=open("all.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2456/330763867.py in <cell line: 0>()
# ----> 1 f=open("all.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'all.txt'

# %%
# try and except

# %%
try:
  f=open('all.txt')
except:
  print("file does not found")
# Out:
# file does not found

# %%
try:
  f=open("ex.txt")
  print(var1)
except:
  print("file does not exists")
# Out:
# file does not exists

# %%
# we need to be specific about what kind of error ewe want to catch

# %%
try:
  f=open('ex.txt')
  print(var1)
except FileNotFoundError:
  print("file does not exists")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2429/1436930632.py in <cell line: 0>()
#       1 try:
#       2   f=open('ex.txt')
# ----> 3   print(var1)
#       4 except FileNotFoundError:
#       5   print("file does not exists")
#
# NameError: name 'var1' is not defined

# %%
try:
    f = open('ex.txt')
    print(var1)

except FileNotFoundError:
    print('file does not exist')

except Exception:
    print("something went wrong")
# Out:
# something went wrong

# %%
try:
  f=open('ex.txt')
  print(var1)
except FileNotFoundError:
  print("file does not exists")
except Exception as e:
         print(e)
# Out:
# name 'var1' is not defined

# %%
# else -> if try block doesnt raise and exception this will run

# %%
try:
  f=open('ex.txt')
except FileNotFoundError:
  print("file doesnt exists")
except Exception as e:
  print(e)
else:
  print(f.read())
  f.close()
# Out:
# this is my ex text file

# %%
try:
  f=open('ex.txt')
except FileNotFoundError:
  print("file doesnt exists")
except Exception as e:
  print(e)
else:
  print(f.read())
  f.close()
finally:
  print("run complete")
# Out:
# this is my ex text file
# run complete

# %%
|f= open('ex.txt')
if f.name=='ex.txt':
  raise Exception
# Out:
#   File "/tmp/ipykernel_2429/308474562.py", line 1
#     |f= open('ex.txt')
#     ^
# SyntaxError: invalid syntax

# %%
# take 2 numbers as user input
# write a program for division of these 2 numbers
# handle zerodivision and valuye error

# %%
try:
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))

    result = num1 / num2
    print("Division =", result)

except ZeroDivisionError:
    print("Cannot divide by zero")

except ValueError:
    print("Please enter valid numbers")
# Out:
# Enter first number: 42
# Enter second number: 0
# Cannot divide by zero
