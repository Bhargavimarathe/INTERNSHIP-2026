# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavimarathe/BhargaviMarathe/blob/main/daily_codes/week4/array_numpy_jun15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# numpy

# %%
import numpy as np

# %%
# creating arrays

# %%
sample_array=np.array([1,2,3,4])

# %%
sample_array
# Out:
# array([1, 2, 3, 4])

# %%
# 2D array(matrix) with 2 rows and 2 columns

# %%
sample_array_2= np.array([[1,2],[3,4]])

# %%
sample_array_2
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
sample_array_2= np.array([[1,2,3,4],[5,6,7,8]])

# %%
sample_array_2
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
# 3D tensor(2 matrices,each with 2 rows and 2 columns)

# %%
sample_tensor_3 = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])

# %%
sample_tensor_3
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
# Dimension

# %%
# 0D array= (Scalar)5
# 1D array = (vector) [1,2,3,4]
# 2D array = (matrix) {rows,columns}
# 3D array = (tensor) (page, rows,columns)

# %%
# array properties

# %%
sample_array=np.array([[1,2,3],[4,5,6]])

# %%
sample_array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# shape

# %%
sample_array.shape
# Out:
# (2, 3)

# %%
sample_array.ndim
# Out:
# 2

# %%
#total_elements

# %%
sample_array.size
# Out:
# 6

# %%
# data type

# %%
sample_array.dtype
# Out:
# dtype('int64')

# %%
# 3d array

# %%
sample_tensor= np.array([[[1,2],[3,4]],[[5,6],[7,8]]])

# %%
sample_tensor
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
# shape

# %%
sample_tensor.shape
# Out:
# (2, 2, 2)

# %%
sample_tensor.ndim
# Out:
# 3

# %%
sample_tensor.size
# Out:
# 8

# %%
sample_tensor.dtype
# Out:
# dtype('int64')

# %%
# special arrays

# %%
np.zeros((2, 3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.arange(0, 10, 2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.linspace(0,1,5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
# indexing and slicing

# %%
sample_array=np.array([10,20,30,40])

# %%
sample_array
# Out:
# array([10, 20, 30, 40])

# %%
sample_array[0]
# Out:
# np.int64(10)

# %%
sample_array[2]
# Out:
# np.int64(30)

# %%
sample_array[-1]
# Out:
# np.int64(40)

# %%
# slicing

# %%
sample_array[1:3]
# Out:
# array([20, 30])

# %%
# array operations

# %%
a=np.array([1,2,3])

# %%
b=np.array([4,5,6])

# %%
a
# Out:
# array([1, 2, 3])

# %%
b
# Out:
# array([4, 5, 6])

# %%
a+b
# Out:
# array([5, 7, 9])

# %%
a-b
# Out:
# array([-3, -3, -3])

# %%
a*b
# Out:
# array([ 4, 10, 18])

# %%
a/b
# Out:
# array([0.25, 0.4 , 0.5 ])

# %%
a%b
# Out:
# array([1, 2, 3])

# %%
a//b
# Out:
# array([0, 0, 0])

# %%
a=np.array([11,22,33])

# %%
b=np.array([22,44,66])

# %%
a+b
# Out:
# array([33, 66, 99])

# %%
a-b
# Out:
# array([-11, -22, -33])

# %%
a*b
# Out:
# array([ 242,  968, 2178])

# %%
a/b
# Out:
# array([0.5, 0.5, 0.5])

# %%
a%b
# Out:
# array([11, 22, 33])

# %%
a//b
# Out:
# array([0, 0, 0])

# %%
# mathematical functions

# %%
sample_array=np.array([1,4,9])

# %%
sample_array
# Out:
# array([1, 4, 9])

# %%
np.sqrt(sample_array)
# Out:
# array([1., 2., 3.])

# %%
sample_array=np.array([27,196,125])

# %%
sample_array
# Out:
# array([ 27, 196, 125])

# %%
np.sqrt(sample_array)
# Out:
# array([ 5.19615242, 14.        , 11.18033989])

# %%
np.exp(sample_array)
# Out:
# array([5.32048241e+11, 1.32348326e+85, 1.93557604e+54])

# %%
sample_array=np.array([26,42,88])

# %%
np.exp(sample_array)
# Out:
# array([1.95729609e+11, 1.73927494e+18, 1.65163625e+38])

# %%
np.log(sample_array)
# Out:
# array([3.25809654, 3.73766962, 4.47733681])

# %%
# statistical funcytions

# %%
sample_array=np.array([1,2,3,4,5])

# %%
sample_array
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.mean(sample_array)
# Out:
# np.float64(3.0)

# %%
np.median(sample_array)
# Out:
# np.float64(3.0)

# %%
np.std(sample_array)
# Out:
# np.float64(1.4142135623730951)

# %%
np.min(sample_array)
# Out:
# np.int64(1)

# %%
np.max(sample_array)
# Out:
# np.int64(5)

# %%
# reshaping array

# %%
sample_array = np.arange(0, 6)

# %%
sample_array
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
 reshaped= sample_array.reshape(2,3)

# %%
reshaped
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
# flattening

# %%
sample_array=np.array([[1,2,],[3,4]])

# %%
sample_array
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
sample_array.flatten()
# Out:
# array([1, 2, 3, 4])

# %%
sample_tnsor_3 = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])e

# %%
sample_tensor_3
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
sample_tensor_3.flatten()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
# joining arrays

# %%
a=np.array([1,2,3])

# %%
b=np.array([4,5,6])

# %%
np.concatenate((a, b))
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
# spliting arrays

# %%
sample_array=np.array([1,2,3,4,5,6])

# %%
sample_array
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
np.split(sample_array, 2)
# Out:
# [array([1, 2, 3]), array([4, 5, 6])]

# %%
# random module

# %%
np.random.rand(3)
# Out:
# array([0.16978189, 0.12916537, 0.26508342])

# %%
np.random.randint(1,10,5)
# Out:
# array([3, 1, 6, 8, 9])

# %%
# Axis concept

# %%
sample_array=np.array([[1,2],[3,4]])

# %%
sample_array
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.sum(sample_array, axis=0) # columns wise sum
# Out:
# array([4, 6])

# %%
np.sum(sample_array, axis=1)  # row wise sum
# Out:
# array([3, 7])

# %%
# NaN and missing values

# %%
sample_array=np.array([1,np.nan,3,4])

# %%
sample_array
# Out:
# array([ 1., nan,  3.,  4.])

# %%
np.isnan(sample_array)
# Out:
# array([False,  True, False, False])

# %%
"""
create 2 numpy arrays and perform element wise addition substraction ,
multipliation and modulas operations
""";

# %%
import numpy as np

a = np.array([10, 20, 30, 40])
b = np.array([2, 4, 5, 8])

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Modulus:", a % b)
# Out:
# Addition: [12 24 35 48]
# Subtraction: [ 8 16 25 32]
# Multiplication: [ 20  80 150 320]
# Modulus: [0 0 0 0]

# %%
import numpy as np

# %%
a=np.arange(1000000)
l= list(a)

# %%
import time
time.time()
# Out:
# 1781588456.0769298

# %%
# time taken by list
start_time = time.time()
new1 = [i * 2 for i in l]
time_taken_l = time.time() - start_time

print(f"Time taken by list is {time_taken_l}")
# Out:
# Time taken by list is 0.05875563621520996

# %%
# time taken by array
start_time = time.time()
newa = a * 2
time_taken_a = time.time() - start_time

print(f"Time taken by an array is {time_taken_a}")
# Out:
# Time taken by an array is 0.003496885299682617

# %%
# how much faster
time_taken_l / time_taken_a
# Out:
# 16.80227722097225
