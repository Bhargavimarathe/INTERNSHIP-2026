# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavimarathe/BhargaviMarathe/blob/main/daily_codes/week3/file_handling_jun11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
create a sample text file with some text in it
""";

# %%
# open the file
f= open("/content/sample.txt")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='/content/sample.txt' mode='r' encoding='utf-8'>

# %%
f= open("sample.txt","r")
print(f.readable())
# Out:
# True

# %%
f.readable()
# Out:
# True

# %%
pwd
# Out:
# '/content'

# %%
f.readline()
# Out:
# 'Technology has become an important part of our daily lives, helping us communicate, learn, and work more efficiently. From smartphones and laptops to online learning platforms, technology makes information accessible within seconds. While it offers many benefits, it is also important to use it responsibly and maintain a balance between digital activities and real-world interactions. As technology continues to evolve, it will create new opportunities and challenges for people around the world.\n'

# %%
f.readline()
# Out:
# ''

# %%
f.readline()
# Out:
# ''

# %%
f=open("sample.txt")

# %%
f.readline(10)
# Out:
# 'Technology'

# %%
f.readline(5)
# Out:
# ' has '

# %%
f.readline()
# Out:
# 'become an important part of our daily lives, helping us communicate, learn, and work more efficiently. From smartphones and laptops to online learning platforms, technology makes information accessible within seconds. While it offers many benefits, it is also important to use it responsibly and maintain a balance between digital activities and real-world interactions. As technology continues to evolve, it will create new opportunities and challenges for people around the world.\n'

# %%
# check readlines

# %%
f=open("sample.txt")

# %%
f.readlines()
# Out:
# ['Technology has become an important part of our daily lives, helping us communicate, learn, and work more efficiently. From smartphones and laptops to online learning platforms, technology makes information accessible within seconds. While it offers many benefits, it is also important to use it responsibly and maintain a balance between digital activities and real-world interactions. As technology continues to evolve, it will create new opportunities and challenges for people around the world.\n',
#  '\n',
#  ' done']

# %%
f.readlines(10)
# Out:
# []

# %%
f.readlines(5)
# Out:
# ['Technology has become an important part of our daily lives, helping us communicate, learn, and work more efficiently. From smartphones and laptops to online learning platforms, technology makes information accessible within seconds. While it offers many benefits, it is also important to use it responsibly and maintain a balance between digital activities and real-world interactions. As technology continues to evolve, it will create new opportunities and challenges for people around the world.\n']

# %%
f=open("sample.txt")

# %%
data= f.readlines()

# %%
data
# Out:
# ['Technology has become an important part of our daily lives, helping us communicate, learn, and work more efficiently. From smartphones and laptops to online learning platforms, technology makes information accessible within seconds. While it offers many benefits, it is also important to use it responsibly and maintain a balance between digital activities and real-world interactions. As technology continues to evolve, it will create new opportunities and challenges for people around the world.\n']

# %%
data=f.readline()

# %%
data
# Out:
# ''

# %%
data= f.readlines()

# %%
for line in data:
  print(line)

# %%
# convert the data in upper case

# %%
f= open("sample.txt")

# %%
data= f.readlines()

# %%
line = "hello world"
data = line.upper()
print(data)
# Out:
# HELLO WORLD

# %%
data= line .upper()
data
# Out:
# 'HELLO WORLD'

# %%
f= open("sample.txt")

# %%
data=f.readlines()

# %%
for line in data:
  print(line.upper())
# Out:
# TECHNOLOGY HAS BECOME AN IMPORTANT PART OF OUR DAILY LIVES, HELPING US COMMUNICATE, LEARN, AND WORK MORE EFFICIENTLY. FROM SMARTPHONES AND LAPTOPS TO ONLINE LEARNING PLATFORMS, TECHNOLOGY MAKES INFORMATION ACCESSIBLE WITHIN SECONDS. WHILE IT OFFERS MANY BENEFITS, IT IS ALSO IMPORTANT TO USE IT RESPONSIBLY AND MAINTAIN A BALANCE BETWEEN DIGITAL ACTIVITIES AND REAL-WORLD INTERACTIONS. AS TECHNOLOGY CONTINUES TO EVOLVE, IT WILL CREATE NEW OPPORTUNITIES AND CHALLENGES FOR PEOPLE AROUND THE WORLD.

# %%
# read function

# %%
f=open("sample.txt")

# %%
f.read()
# Out:
# 'Technology has become an important part of our daily lives, helping us communicate, learn, and work more efficiently. From smartphones and laptops to online learning platforms, technology makes information accessible within seconds. While it offers many benefits, it is also important to use it responsibly and maintain a balance between digital activities and real-world interactions. As technology continues to evolve, it will create new opportunities and challenges for people around the world.\n'

# %%
f=open("sample.txt")

# %%
text= f.read()

# %%
text
# Out:
# 'Technology has become an important part of our daily lives, helping us communicate, learn, and work more efficiently. From smartphones and laptops to online learning platforms, technology makes information accessible within seconds. While it offers many benefits, it is also important to use it responsibly and maintain a balance between digital activities and real-world interactions. As technology continues to evolve, it will create new opportunities and challenges for people around the world.\n'

# %%
print(text)
# Out:
# Technology has become an important part of our daily lives, helping us communicate, learn, and work more efficiently. From smartphones and laptops to online learning platforms, technology makes information accessible within seconds. While it offers many benefits, it is also important to use it responsibly and maintain a balance between digital activities and real-world interactions. As technology continues to evolve, it will create new opportunities and challenges for people around the world.

# %%
text.split()
# Out:
# ['Technology',
#  'has',
#  'become',
#  'an',
#  'important',
#  'part',
#  'of',
#  'our',
#  'daily',
#  'lives,',
#  'helping',
#  'us',
#  'communicate,',
#  'learn,',
#  'and',
#  'work',
#  'more',
#  'efficiently.',
#  'From',
#  'smartphones',
#  'and',
#  'laptops',
#  'to',
#  'online',
#  'learning',
#  'platforms,',
#  'technology',
#  'makes',
#  'information',
#  'accessible',
#  'within',
#  'seconds.',
#  'While',
#  'it',
#  'offers',
#  'many',
#  'benefits,',
#  'it',
#  'is',
#  'also',
#  'important',
#  'to',
#  'use',
#  'it',
#  'responsibly',
#  'and',
#  'maintain',
#  'a',
#  'balance',
#  'between',
#  'digital',
#  'activities',
#  'and',
#  'real-world',
#  'interactions.',
#  'As',
#  'technology',
#  'continues',
#  'to',
#  'evolve,',
#  'it',
#  'will',
#  'create',
#  'new',
#  'opportunities',
#  'and',
#  'challenges',
#  'for',
#  'people',
#  'around',
#  'the',
#  'world.']

# %%
"""
create a text file with some text in marathi
"""
# Out:
# '\ncreate a text file with some text in marathi \n'

# %%
m=open("/content/marathiii.txt")

# %%
print(m.read())
# Out:
# ﻿तंत्रज्ञान आजच्या जीवनाचा एक महत्त्वाचा भाग बनले आहे. मोबाईल,
# संगणक आणि इंटरनेटमुळे आपले अनेक कामे सोपी झाली आहेत.
#  विद्यार्थ्यांना ऑनलाइन शिक्षण घेता येते आणि माहिती सहज मिळते.
# तंत्रज्ञानाचा योग्य वापर केल्यास वेळ व मेहनत दोन्हीची बचत होते

# %%
m=open("marathiii.txt","r",encoding="utf-8")
print(m.read())
m.close()
# Out:
# ﻿तंत्रज्ञान आजच्या जीवनाचा एक महत्त्वाचा भाग बनले आहे. मोबाईल,
# संगणक आणि इंटरनेटमुळे आपले अनेक कामे सोपी झाली आहेत.
#  विद्यार्थ्यांना ऑनलाइन शिक्षण घेता येते आणि माहिती सहज मिळते.
# तंत्रज्ञानाचा योग्य वापर केल्यास वेळ व मेहनत दोन्हीची बचत होते

# %%
m.readable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_589/787536634.py in <cell line: 0>()
# ----> 1 m.readable()
#
# ValueError: I/O operation on closed file

# %%
# opening a file with context manager

# %%
with open('sample.txt')as f:
  data= f.read()

# %%
print(data)
# Out:
# Technology has become an important part of our daily lives, helping us communicate, learn, and work more efficiently. From smartphones and laptops to online learning platforms, technology makes information accessible within seconds. While it offers many benefits, it is also important to use it responsibly and maintain a balance between digital activities and real-world interactions. As technology continues to evolve, it will create new opportunities and challenges for people around the world.

# %%
# writing in a file

# %%
f=open('myfile.text' ,'w')

# %%
f.readable()
# Out:
# False

# %%
f.writable()
# Out:
# True

# %%
lines=['frode took the ring.','he started his journey to mount doom.']

# %%
f.writelines(lines)

# %%
f.close()

# %%
# writelines -> tskes the list of sentences from user and writes in the file

# %%
# write

# %%
sent= 'frode took the ring.','he started his journey to mount doom.'

# %%
sent = "Hello World, i am learning python"

f = open("myfile.txt", "w")
f.write(sent)
f.close()

# %%
# write into a myfile.text with context manager
# use write function and add 3 separate lines

# %%
with open('myfile.tct','w') as f:
  f.write('this is first line\n')
  f.write('this is second line\n')
  f.write('this is third line\n')

# %%
# sample file copy operation

# %%
s=open('sample.txt','r')
f=open('myfile.txt','w')

# %%
contents=s.read()
f.write(contents)
f.close()

# %%
# append

# %%
s=open('sample.txt','a')

# %%
s.write('\n done')
# Out:
# 6

# %%
s.close()

# %%
  f.seek(10)
# Out:
# 10

# %%
f.tell()
# Out:
# 10

# %%
         =
